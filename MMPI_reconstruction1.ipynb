# %%
import matlab_util as mu
reload(mu)
import tree_util as tu
reload(tu)
import scoring
reload(scoring)
import barcode
reload(barcode)
import cluster_diffusion as cdiff
reload(cdiff)

import scipy.io
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
mdict = scipy.io.loadmat('/users/jerrod/Google Drive/Yale_Research/Questionnaire_2D_20130614/Examples/Output_MMPI2/EMD_basic_1/MMPI2_package.mat')

fold_sensors = mdict['fold_sensors']
fold_points = mdict['fold_points']

row_tree = mu.matlab_to_pyquest(fold_sensors)
col_tree = mu.matlab_to_pyquest(fold_points)

mdict2 = scipy.io.loadmat('/users/jerrod/Google Drive/Yale_Research/Questionnaire_2D_20130614/Examples/Output_MMPI2/EMD_basic_1/MMPI2_basic.mat')
data = mdict2['matrix']

coefs = tu.bitree_transform(data,row_tree,col_tree)
recon_matrix, coefs_used = tu.inverse_bitree_transform(coefs,row_tree,col_tree,0.01)
score = scoring.Score(data,recon_matrix)

# %%
fig = plt.figure(figsize=(20,20))
plt.imshow(data,cmap='binary',interpolation='nearest')
plt.title('Raw data')
plt.show()

fig = plt.figure(figsize=(20,20))
plt.imshow(score.classifier,cmap='binary',interpolation='nearest')
plt.title('Reconstructed matrix')
plt.show()

fig = plt.figure(figsize=(20,20))
plt.imshow(barcode.organize_folders(row_tree,col_tree,data),cmap='binary',interpolation='nearest')
plt.title('Raw data organized by folders')
plt.show()

fig = plt.figure(figsize=(20,20))
plt.imshow(barcode.organize_folders(row_tree,col_tree,recon_matrix),cmap='binary',interpolation='nearest')
plt.title('Reconstructed matrix organized by folders')
plt.show()

# %%
score.class_pct
# Out:
# 0.70879567886706818

# %%
mdict = scipy.io.loadmat('/users/jerrod/Google Drive/Yale_Research/Questionnaire_2D_20130614/Examples/Output_MMPI2_AntiQuestions/MMPI2_AntiQuestions_package.mat')

fold_sensors = mdict['fold_sensors']
fold_points = mdict['fold_points']

row_tree = mu.matlab_to_pyquest(fold_sensors)
col_tree = mu.matlab_to_pyquest(fold_points)

mdict2 = scipy.io.loadmat('/users/jerrod/Google Drive/Yale_Research/Questionnaire_2D_20130614/Examples/Output_MMPI2_AntiQuestions/MMPI2_AntiQuestions_basic.mat')
data = mdict2['matrix']

coefs = tu.bitree_transform(data,row_tree,col_tree)
recon_matrix, coefs_used = tu.inverse_bitree_transform(coefs,row_tree,col_tree,0.005)
score = scoring.Score(data,recon_matrix)

# %%
score.class_pct
# Out:
# 0.70384435626102293

# %%
# Out:
# (1134L, 2000L)

# %%
np.sum(np.abs(score.classifier[0:567,:] + score.classifier[567:,:]))
# Out:
# 56542.0

# %%
score.recon_data[0,0:10]
# Out:
# array([-0.18083831, -0.30095705, -0.3648345 , -0.23063688, -0.26120401,
#        -0.1795745 , -0.26678348, -0.01701059, -0.3019838 , -0.33414329])

# %%
score.recon_data[567,0:10]
# Out:
# array([ 0.1637675 ,  0.27240687,  0.51417014,  0.20114247,  0.42147471,
#         0.32914072,  0.41658305,  0.17752855,  0.46010123,  0.48556128])

# %%
row_nodes = row_tree.level_nodes(7)
col_nodes = col_tree.level_nodes(7)
print len(row_nodes),len(col_nodes)
# Out:
# 64 64

# %%
recon_matrix = np.zeros(np.shape(data))
for row_node in row_nodes:
    for col_node in col_nodes:
        bc = barcode.bifolder_average(row_node,col_node,data)
#      for ridx,row in enumerate(row_node.elements):
        for col in col_node.elements:
            recon_matrix[row_node.elements,col] = bc[ridx]

# %%
score = scoring.Score(data,recon_matrix)

# %%
score.class_pct
# Out:
# 0.68325529100529103

# %%
mdict = scipy.io.loadmat('/users/jerrod/Google Drive/Yale_Research/Questionnaire_2D_20130614/Examples/Output_MMPI2/MMPI2_package.mat')

fold_sensors = mdict['fold_sensors']
fold_points = mdict['fold_points']

row_tree = mu.matlab_to_pyquest(fold_sensors)
col_tree = mu.matlab_to_pyquest(fold_points)

mdict2 = scipy.io.loadmat('/users/jerrod/Google Drive/Yale_Research/Questionnaire_2D_20130614/Examples/Output_MMPI2/MMPI2_basic.mat')
data = mdict2['matrix']

coefs = tu.bitree_transform(data,row_tree,col_tree)
recon_matrix, coefs_used = tu.inverse_bitree_transform(coefs,row_tree,col_tree,0.01)
score = scoring.Score(data,recon_matrix)
score.class_pct
# Out:
# 0.64948397444278827
