# %%
from imports import *

# %%
def view_tree(tree,vecs,vals,descs=None,tree_desc=""):
    viewer_files.write_tree_viewer("temp.pickle",tree,vecs,vals,descs,tree_desc)
    # %run tree_viewer.py temp.pickle

# %%
# %run load_data.py de

# %%
ROW_ALPHA = 1.0
COL_ALPHA = 1.0

# %%
row_tree,col_tree,row_vecs,col_vecs,row_vals,col_vals = quest.pyquest_newtree(data,tree_constant=0.2,row_alpha=ROW_ALPHA,col_alpha=COL_ALPHA,beta=1.0,n_iters=5)

# %%
#viewer_files.write_question_viewer("qv.pickle",data,row_tree,col_tree,row_vecs,row_vals,col_vecs,col_vals,descs=q_descs)

# %%
#view_tree(row_tree,row_vecs,row_vals)

# %%
#view_tree(col_tree,col_vecs,col_vals)

# %%
recon = tree_recon.recon_2d_sure(data,row_tree,col_tree)

# %%
cplot(recon)

# %%
cplot(barcode.organize_folders(row_tree,col_tree,1.01*data))
plt.show()
cplot(barcode.organize_folders(row_tree,col_tree,recon))
plt.show()

# %%
flip_pct = 0.05
new_data = data.copy()
flips = np.random.rand(*data.shape).argsort(None)[0:int(flip_pct*np.product(data.shape))]
fps = np.unravel_index(flips,data.shape)
for (x,y) in zip(fps[0],fps[1]):
    new_data[x,y] *= -1
new_row_tree,new_col_tree,row_vecs,col_vecs,row_vals,col_vals = quest.pyquest_newtree(new_data,tree_constant=0.2,row_alpha=ROW_ALPHA,col_alpha=COL_ALPHA,beta=1.0,n_iters=5)
new_recon = tree_recon.recon_2d_sure(new_data,row_tree,col_tree)

# %%
cplot(barcode.organize_folders(row_tree,col_tree,new_recon))
plt.show()
cplot(barcode.organize_folders(row_tree,col_tree,recon))
plt.show()

# %%
np.sum(np.abs(recon-new_recon))/np.product(data.shape)
# Out:
# 0.048503963269240592

# %%
np.sum(np.sign(recon)==np.sign(new_recon))/(576.0*2428)
# Out:
# 0.96733279562511443
