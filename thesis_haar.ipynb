# %%
reload(haar)
from imports import *
t = tree.dyadic_tree(2)

ft = tree.ClusterTreeNode(range(10))
ft.create_subclusters([0,0,1,1,1,2,2,2,2,3])
for child in ft.children:
    child.create_subclusters(range(child.size))
ft.make_index()

# %%
import tree_plot

# %%
tree_plot.plot_tree(ft)

# %%
tr = t
COLORS = "rbgk"
hb,nodes = haar.compute_haar(tr,True,"L1")
for i in xrange(tr.size):
    if nodes[i] == -1:
        l = 0
    else:
        l = tr[nodes[i]].level
    plt.step(np.arange(0,tr.size+1),np.concatenate([hb[:,i],hb[-1:,i]]),color=COLORS[l],where='post')
    plt.ylim(np.min(hb)*1.02,np.max(hb)*1.02)
    plt.show()

# %%
hb = haar.compute_haar(ft,False,"L1")
for i in xrange(hb.shape[0]):
    for j in xrange(hb.shape[0]):
        cplot(1.01*np.outer(hb[:,i],hb[:,j]))
        plt.show()
